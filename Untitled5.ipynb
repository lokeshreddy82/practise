# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshreddy82/practise/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **#pandas package explanation indetail**

# %%
import pandas as pd

# %%
lokesh=pd.read_csv("/content/sample_data/california_housing_test.csv")
lokesh.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
weather_data={
    'rain_dates' :['1/1/2023','2/5/2022','3/7/2020','8/12/2002','5/6/2022','12/12/2022'],
    'weather' :['rainy','summer','winter','cloudy','rainy','cloudy'],
    'temparature' :[5,4,8,12,9,3],
    'days' :['monday','tuesday','wednesday','thusday','friday','saturday']
}#this is dictnory and i can use to create dataframe

# %%
n=pd.DataFrame(weather_data)
n
# Out:
#    rain_dates weather  temparature       days
# 0    1/1/2023   rainy            5     monday
# 1    2/5/2022  summer            4    tuesday
# 2    3/7/2020  winter            8  wednesday
# 3   8/12/2002  cloudy           12    thusday
# 4    5/6/2022   rainy            9     friday
# 5  12/12/2022  cloudy            3   saturday

# %%
n.head(2)
# Out:
#   rain_dates weather  temparature     days
# 0   1/1/2023   rainy            5   monday
# 1   2/5/2022  summer            4  tuesday

# %%
n.tail(2)
# Out:
#    rain_dates weather  temparature      days
# 4    5/6/2022   rainy            9    friday
# 5  12/12/2022  cloudy            3  saturday

# %%
n["temparature"].describe()
# Out:
# count     6.000000
# mean      6.833333
# std       3.430258
# min       3.000000
# 25%       4.250000
# 50%       6.500000
# 75%       8.750000
# max      12.000000
# Name: temparature, dtype: float64

# %%
n.set_index("rain_dates",inplace=True)
n
# Out:
#            weather  temparature       days
# rain_dates
# 1/1/2023     rainy            5     monday
# 2/5/2022    summer            4    tuesday
# 3/7/2020    winter            8  wednesday
# 8/12/2002   cloudy           12    thusday
# 5/6/2022     rainy            9     friday
# 12/12/2022  cloudy            3   saturday

# %%
n.reset_index(inplace=True)
n
# Out:
#    level_0  index  rain_dates weather  temparature       days
# 0        0      0    1/1/2023   rainy            5     monday
# 1        1      1    2/5/2022  summer            4    tuesday
# 2        2      2    3/7/2020  winter            8  wednesday
# 3        3      3   8/12/2002  cloudy           12    thusday
# 4        4      4    5/6/2022   rainy            9     friday
# 5        5      5  12/12/2022  cloudy            3   saturday

# %%
new=n.replace(5,NaN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e196ded56090> in <cell line: 1>()
# ----> 1 new=n.replace(5,NaN)
#
# NameError: name 'NaN' is not defined
